# %% [markdown]
# # ViT classification pipeline

# %%
from google.colab import drive
from keras.activations import sigmoid
from keras.layers import Dense, Input
from keras.losses import BinaryCrossentropy
from keras.optimizers import Adam
from keras.models import Sequential, Model

import numpy as np
import pathlib
from PIL import Image

from sklearn.metrics import accuracy_score

from transformers import ViTImageProcessor, ViTModel, ViTConfig, TFAutoModel, ViTForImageClassification
from transformers import TrainingArguments, Trainer, TFViTForImageClassification
import tensorflow as tf
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading and Preprocessing Data

# %%
batch_size=32

# %%
drive.mount('/content/drive')
N_TRAIN = 1250
N_VAL = 250

#paths to LR and HR images
real_bicubic_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Real/Bicubic')
real_sr3_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Real/SR3')
real_srgan_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Real/SRGAN')
real_srcnn_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Real/SRCNN')

baseline_bicubic_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Baseline/Bicubic')
baseline_sr3_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Baseline/SR3')
baseline_srgan_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Baseline/SRGAN')
baseline_srcnn_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Baseline/SRCNN')

adversarial_bicubic_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Adversarial Attack/Bicubic')
adversarial_sr3_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Adversarial Attack/SR3')
adversarial_srgan_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Adversarial Attack/SRGAN')
adversarial_srcnn_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Adversarial Attack/SRCNN')

faceshift_bicubic_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Faceshift/Bicubic')
faceshift_sr3_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Faceshift/SR3')
faceshift_srgan_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Faceshift/SRGAN')
faceshift_srcnn_dir = pathlib.Path('/content/drive/MyDrive/ST456_project_team_afi/DFGC/Faceshift/SRCNN')

real_bicubic_paths = sorted([str(path) for path in real_bicubic_dir.glob('*.png')])
real_sr3_paths = sorted([str(path) for path in real_sr3_dir.glob('*.png')])
real_srgan_paths = sorted([str(path) for path in real_srgan_dir.glob('*.png')])
real_srcnn_paths = sorted([str(path) for path in real_srcnn_dir.glob('*.png')])

baseline_bicubic_paths = sorted([str(path) for path in baseline_bicubic_dir.glob('*.png')])
baseline_sr3_paths = sorted([str(path) for path in baseline_sr3_dir.glob('*.png')])
baseline_srgan_paths = sorted([str(path) for path in baseline_srgan_dir.glob('*.png')])
baseline_srcnn_paths = sorted([str(path) for path in baseline_srcnn_dir.glob('*.png')])

adversarial_bicubic_paths = sorted([str(path) for path in adversarial_bicubic_dir.glob('*.png')])
adversarial_sr3_paths = sorted([str(path) for path in adversarial_sr3_dir.glob('*.png')])
adversarial_srgan_paths = sorted([str(path) for path in adversarial_srgan_dir.glob('*.png')])
adversarial_srcnn_paths = sorted([str(path) for path in adversarial_srcnn_dir.glob('*.png')])

faceshift_bicubic_paths = sorted([str(path) for path in faceshift_bicubic_dir.glob('*.png')])
faceshift_sr3_paths = sorted([str(path) for path in faceshift_sr3_dir.glob('*.png')])
faceshift_srgan_paths = sorted([str(path) for path in faceshift_srgan_dir.glob('*.png')])
faceshift_srcnn_paths = sorted([str(path) for path in faceshift_srcnn_dir.glob('*.png')])
# Out:
# Mounted at /content/drive

# %%
def train_val_test_split(real_paths, fake_paths, n_train=N_TRAIN, n_val=N_VAL):
  """
  Split the dataset into training, validation, and test sets.

  Args:
    real_paths (list): List of real images paths.
    fake_paths (list): List of fake images paths.
    n_train (int): Number of training images.
    n_val (int): Number of validation images.
  Returns:
    real_train (list): List of real training images paths.
    fake_train (list): List of fake training images paths.
    real_val (list): List of real validation images paths.
    fake_val (list): List of fake validation images paths.
    real_test (list): List of real test images paths.
    fake_test (list): List of fake test images paths.
  """
  length = min([len(real_paths), len(fake_paths)])
  real_train = real_paths[:n_train//2]
  fake_train = fake_paths[:n_train//2]
  real_val = real_paths[n_train//2:n_train//2+n_val//2]
  fake_val = fake_paths[n_train//2:n_train//2+n_val//2]
  real_test = real_paths[n_train//2+n_val//2:length]
  fake_test = fake_paths[n_train//2+n_val//2:length]
  return real_train, fake_train, real_val, fake_val, real_test, fake_test
#
(bicubic_real_train,
 bicubic_baseline_train,
 bicubic_real_val,
 bicubic_baseline_val,
 bicubic_real_test,
 bicubic_baseline_test) =  train_val_test_split(real_bicubic_paths, baseline_bicubic_paths)

(bicubic_real_train,
 bicubic_adversarial_train,
 bicubic_real_val,
 bicubic_adversarial_val,
 bicubic_real_test,
 bicubic_adversarial_test) =  train_val_test_split(real_bicubic_paths, adversarial_bicubic_paths)

(bicubic_real_train,
 bicubic_faceshift_train,
 bicubic_real_val,
 bicubic_faceshift_val,
 bicubic_real_test,
 bicubic_faceshift_test) =  train_val_test_split(real_bicubic_paths, faceshift_bicubic_paths)
#
(srgan_real_train,
 srgan_baseline_train,
 srgan_real_val,
 srgan_baseline_val,
 srgan_real_test,
 srgan_baseline_test) =  train_val_test_split(real_srgan_paths, baseline_srgan_paths)

(srgan_real_train,
 srgan_adversarial_train,
 srgan_real_val,
 srgan_adversarial_val,
 srgan_real_test,
 srgan_adversarial_test) =  train_val_test_split(real_srgan_paths, adversarial_srgan_paths)

(srgan_real_train,
 srgan_faceshift_train,
 srgan_real_val,
 srgan_faceshift_val,
 srgan_real_test,
 srgan_faceshift_test) =  train_val_test_split(real_srgan_paths, faceshift_srgan_paths)
#
(srcnn_real_train,
 srcnn_baseline_train,
 srcnn_real_val,
 srcnn_baseline_val,
 srcnn_real_test,
 srcnn_baseline_test) =  train_val_test_split(real_srcnn_paths, baseline_srcnn_paths)

(srcnn_real_train,
 srcnn_adversarial_train,
 srcnn_real_val,
 srcnn_adversarial_val,
 srcnn_real_test,
 srcnn_adversarial_test) =  train_val_test_split(real_srcnn_paths, adversarial_srcnn_paths)

(srcnn_real_train,
 srcnn_faceshift_train,
 srcnn_real_val,
 srcnn_faceshift_val,
 srcnn_real_test,
 srcnn_faceshift_test) =  train_val_test_split(real_srcnn_paths, faceshift_srcnn_paths)

#
(sr3_real_train,
 sr3_baseline_train,
 sr3_real_val,
 sr3_baseline_val,
 sr3_real_test,
 sr3_baseline_test) =  train_val_test_split(real_sr3_paths, baseline_sr3_paths, n_train=150, n_val=0)

(sr3_real_train,
 sr3_adversarial_train,
 sr3_real_val,
 sr3_adversarial_val,
 sr3_real_test,
 sr3_adversarial_test) =  train_val_test_split(real_sr3_paths, adversarial_sr3_paths, n_train=150, n_val=0)

(sr3_real_train,
 sr3_faceshift_train,
 sr3_real_val,
 sr3_faceshift_val,
 sr3_real_test,
 sr3_faceshift_test) =  train_val_test_split(real_sr3_paths, faceshift_sr3_paths, n_train=150, n_val=0)

# %%
# load image processor
processor = ViTImageProcessor.from_pretrained('google/vit-base-patch16-224-in21k')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]

# %%
# @tf.function
def create_x_y(real_paths, fake_paths):
  """
  Preprocess images and labels for training.

  Args:
    real_paths: list of paths to real images.
    fake_paths: list of paths to deepfaked images.
  Returns:
    train_x: list of preprocessed images.
    train_y: list of labels.
  """
  train_x = []
  train_y = []
  for path in tqdm(real_paths):
    img = tf.io.read_file(path)
    img = tf.image.decode_png(img, channels=3)
    img = processor(images=img, return_tensors="pt")

    train_x.append(img["pixel_values"][0])
    train_y.append(0)

  for path in tqdm(fake_paths):
    img = tf.io.read_file(path)
    img = tf.image.decode_png(img, channels=3)
    img = processor(images=img, return_tensors="pt")
    train_x.append(img["pixel_values"][0])
    train_y.append(1)

  train_x = np.array(train_x)
  train_y = np.array(train_y)
  return train_x, train_y

# %% [markdown]
# ## SRGAN

# %%
train_x, train_y = create_x_y(srgan_real_train, srgan_faceshift_train)
val_x, val_y = create_x_y(srgan_real_val, srgan_faceshift_val)
test_x, test_y = create_x_y(srgan_real_test, srgan_faceshift_test)

# load ViT model from huggingface
vit = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k',num_labels=1, ignore_mismatched_sizes=True)
# freeze the ViT layer but while making the final classification layer trainable
# this is crucial as fine-tuning the entire model would take very long
# instead we use transfer learning to classify based of the features extracted by the ViT
vit.trainable = True
vit.layers[0].trainable = False
vit.layers[-1].kernel_regularizer = tf.keras.regularizers.l1_l2(0.01, 0.01)
vit.layers[-1].activation = tf.keras.activations.sigmoid
vit.summary()
# compile, train and evaluate the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
vit.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
vit.fit(train_x, train_y, validation_data=(val_x, val_y), epochs=30)
vit.evaluate(test_x, test_y)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing TFViTForImageClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTForImageClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTForImageClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_vi_t_for_image_classification_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  85798656
#
#  classifier (Dense)          multiple                  769
#
# =================================================================
# Total params: 85799425 (327.30 MB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 85798656 (327.30 MB)
# _________________________________________________________________
# Epoch 1/30
# 40/40 [==============================] - 52s 518ms/step - loss: 0.5895 - accuracy: 0.7992 - val_loss: 0.6255 - val_accuracy: 0.5480
# Epoch 2/30
# 40/40 [==============================] - 11s 279ms/step - loss: 0.4512 - accuracy: 0.8904 - val_loss: 0.5716 - val_accuracy: 0.6440
# Epoch 3/30
# 40/40 [==============================] - 11s 279ms/step - loss: 0.3730 - accuracy: 0.9056 - val_loss: 0.5153 - val_accuracy: 0.7600
# Epoch 4/30
# 40/40 [==============================] - 11s 277ms/step - loss: 0.3214 - accuracy: 0.9344 - val_loss: 0.4608 - val_accuracy: 0.8160
# Epoch 5/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2823 - accuracy: 0.9504 - val_loss: 0.4211 - val_accuracy: 0.8440
# Epoch 6/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2526 - accuracy: 0.9600 - val_loss: 0.3846 - val_accuracy: 0.8560
# Epoch 7/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2288 - accuracy: 0.9664 - val_loss: 0.3572 - val_accuracy: 0.8640
# Epoch 8/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2090 - accuracy: 0.9728 - val_loss: 0.3337 - val_accuracy: 0.8600
# Epoch 9/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1924 - accuracy: 0.9728 - val_loss: 0.3070 - val_accuracy: 0.8800
# Epoch 10/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.1780 - accuracy: 0.9776 - val_loss: 0.2911 - val_accuracy: 0.9000
# Epoch 11/30
# 40/40 [==============================] - 11s 277ms/step - loss: 0.1656 - accuracy: 0.9784 - val_loss: 0.2756 - val_accuracy: 0.9040
# Epoch 12/30
# 40/40 [==============================] - 11s 278ms/step - loss: 0.1546 - accuracy: 0.9792 - val_loss: 0.2584 - val_accuracy: 0.9120
# Epoch 13/30
# 40/40 [==============================] - 11s 277ms/step - loss: 0.1455 - accuracy: 0.9824 - val_loss: 0.2459 - val_accuracy: 0.9120
# Epoch 14/30
# 40/40 [==============================] - 11s 277ms/step - loss: 0.1365 - accuracy: 0.9840 - val_loss: 0.2367 - val_accuracy: 0.9120
# Epoch 15/30
# 40/40 [==============================] - 11s 278ms/step - loss: 0.1293 - accuracy: 0.9840 - val_loss: 0.2253 - val_accuracy: 0.9160
# Epoch 16/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.1223 - accuracy: 0.9864 - val_loss: 0.2195 - val_accuracy: 0.9200
# Epoch 17/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1161 - accuracy: 0.9864 - val_loss: 0.2142 - val_accuracy: 0.9160
# Epoch 18/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.1107 - accuracy: 0.9872 - val_loss: 0.2066 - val_accuracy: 0.9240
# Epoch 19/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.1055 - accuracy: 0.9888 - val_loss: 0.2003 - val_accuracy: 0.9280
# Epoch 20/30
# 40/40 [==============================] - 11s 277ms/step - loss: 0.1006 - accuracy: 0.9888 - val_loss: 0.1938 - val_accuracy: 0.9280
# Epoch 21/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.0964 - accuracy: 0.9904 - val_loss: 0.1877 - val_accuracy: 0.9280
# Epoch 22/30
# 40/40 [==============================] - 11s 277ms/step - loss: 0.0923 - accuracy: 0.9912 - val_loss: 0.1859 - val_accuracy: 0.9280
# Epoch 23/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.0884 - accuracy: 0.9912 - val_loss: 0.1803 - val_accuracy: 0.9280
# Epoch 24/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0849 - accuracy: 0.9920 - val_loss: 0.1753 - val_accuracy: 0.9280
# Epoch 25/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.0818 - accuracy: 0.9936 - val_loss: 0.1711 - val_accuracy: 0.9280
# Epoch 26/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.0789 - accuracy: 0.9928 - val_loss: 0.1681 - val_accuracy: 0.9280
# Epoch 27/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0759 - accuracy: 0.9936 - val_loss: 0.1642 - val_accuracy: 0.9320
# Epoch 28/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0733 - accuracy: 0.9936 - val_loss: 0.1606 - val_accuracy: 0.9320
# Epoch 29/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.0708 - accuracy: 0.9936 - val_loss: 0.1571 - val_accuracy: 0.9320
# Epoch 30/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0683 - accuracy: 0.9936 - val_loss: 0.1556 - val_accuracy: 0.9320
# 16/16 [==============================] - 4s 231ms/step - loss: 0.1260 - accuracy: 0.9679
# [0.12604999542236328, 0.9678714871406555]

# %%
train_x, train_y = create_x_y(srgan_real_train, srgan_baseline_train)
val_x, val_y = create_x_y(srgan_real_val, srgan_baseline_val)
test_x, test_y = create_x_y(srgan_real_test, srgan_baseline_test)
# reload model to reset weights
vit = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k',num_labels=1, ignore_mismatched_sizes=True)
vit.trainable = True
vit.layers[0].trainable = False
vit.layers[-1].kernel_regularizer = tf.keras.regularizers.l1_l2(0.01, 0.01)
vit.layers[-1].activation = tf.keras.activations.sigmoid
vit.summary()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

vit.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
vit.fit(train_x, train_y, validation_data=(val_x, val_y), epochs=30)
vit.evaluate(test_x, test_y)
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
#   0%|          | 0/250 [00:00<?, ?it/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing TFViTForImageClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTForImageClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTForImageClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_vi_t_for_image_classification_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  85798656
#
#  classifier (Dense)          multiple                  769
#
# =================================================================
# Total params: 85799425 (327.30 MB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 85798656 (327.30 MB)
# _________________________________________________________________
# Epoch 1/30
# 40/40 [==============================] - 43s 494ms/step - loss: 0.6447 - accuracy: 0.6600 - val_loss: 0.7544 - val_accuracy: 0.4640
# Epoch 2/30
# 40/40 [==============================] - 11s 278ms/step - loss: 0.5850 - accuracy: 0.7008 - val_loss: 0.8051 - val_accuracy: 0.4760
# Epoch 3/30
# 40/40 [==============================] - 11s 279ms/step - loss: 0.5569 - accuracy: 0.7160 - val_loss: 0.8140 - val_accuracy: 0.4800
# Epoch 4/30
# 40/40 [==============================] - 11s 277ms/step - loss: 0.5382 - accuracy: 0.7240 - val_loss: 0.8168 - val_accuracy: 0.4800
# Epoch 5/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.5211 - accuracy: 0.7392 - val_loss: 0.8310 - val_accuracy: 0.4960
# Epoch 6/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.5079 - accuracy: 0.7504 - val_loss: 0.8376 - val_accuracy: 0.5200
# Epoch 7/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.4955 - accuracy: 0.7616 - val_loss: 0.8017 - val_accuracy: 0.5320
# Epoch 8/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4844 - accuracy: 0.7768 - val_loss: 0.8155 - val_accuracy: 0.5480
# Epoch 9/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.4757 - accuracy: 0.7752 - val_loss: 0.8287 - val_accuracy: 0.5480
# Epoch 10/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.4670 - accuracy: 0.7792 - val_loss: 0.8505 - val_accuracy: 0.5520
# Epoch 11/30
# 40/40 [==============================] - 11s 277ms/step - loss: 0.4601 - accuracy: 0.7920 - val_loss: 0.8533 - val_accuracy: 0.5560
# Epoch 12/30
# 40/40 [==============================] - 11s 277ms/step - loss: 0.4535 - accuracy: 0.7952 - val_loss: 0.8307 - val_accuracy: 0.5520
# Epoch 13/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.4455 - accuracy: 0.7952 - val_loss: 0.8447 - val_accuracy: 0.5680
# Epoch 14/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.4381 - accuracy: 0.8048 - val_loss: 0.8488 - val_accuracy: 0.5680
# Epoch 15/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.4316 - accuracy: 0.8128 - val_loss: 0.8438 - val_accuracy: 0.5640
# Epoch 16/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.4260 - accuracy: 0.8112 - val_loss: 0.8456 - val_accuracy: 0.5640
# Epoch 17/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.4206 - accuracy: 0.8224 - val_loss: 0.8441 - val_accuracy: 0.5680
# Epoch 18/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.4158 - accuracy: 0.8168 - val_loss: 0.8453 - val_accuracy: 0.5720
# Epoch 19/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.4105 - accuracy: 0.8328 - val_loss: 0.8402 - val_accuracy: 0.5680
# Epoch 20/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.4073 - accuracy: 0.8352 - val_loss: 0.8362 - val_accuracy: 0.5680
# Epoch 21/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.4017 - accuracy: 0.8264 - val_loss: 0.8652 - val_accuracy: 0.5680
# Epoch 22/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.3982 - accuracy: 0.8376 - val_loss: 0.8494 - val_accuracy: 0.5640
# Epoch 23/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.3939 - accuracy: 0.8360 - val_loss: 0.8623 - val_accuracy: 0.5720
# Epoch 24/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.3888 - accuracy: 0.8416 - val_loss: 0.8589 - val_accuracy: 0.5720
# Epoch 25/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.3856 - accuracy: 0.8392 - val_loss: 0.8566 - val_accuracy: 0.5720
# Epoch 26/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.3812 - accuracy: 0.8416 - val_loss: 0.8626 - val_accuracy: 0.5680
# Epoch 27/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.3774 - accuracy: 0.8560 - val_loss: 0.8368 - val_accuracy: 0.5680
# Epoch 28/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.3749 - accuracy: 0.8488 - val_loss: 0.8463 - val_accuracy: 0.5720
# Epoch 29/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.3699 - accuracy: 0.8560 - val_loss: 0.8499 - val_accuracy: 0.5760
# Epoch 30/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.3664 - accuracy: 0.8576 - val_loss: 0.8594 - val_accuracy: 0.5760
# 16/16 [==============================] - 4s 233ms/step - loss: 0.7507 - accuracy: 0.6433
# [0.750725269317627, 0.6432865858078003]

# %%
train_x, train_y = create_x_y(srgan_real_train, srgan_adversarial_train)
val_x, val_y = create_x_y(srgan_real_val, srgan_adversarial_val)
test_x, test_y = create_x_y(srgan_real_test, srgan_adversarial_test)

vit = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k',num_labels=1, ignore_mismatched_sizes=True)
vit.trainable = True
vit.layers[0].trainable = False
vit.layers[-1].kernel_regularizer = tf.keras.regularizers.l1_l2(0.01, 0.01)
vit.layers[-1].activation = tf.keras.activations.sigmoid
vit.summary()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

vit.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
vit.fit(train_x, train_y, validation_data=(val_x, val_y), epochs=30)
vit.evaluate(test_x, test_y)
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
#   0%|          | 0/250 [00:00<?, ?it/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing TFViTForImageClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTForImageClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTForImageClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_vi_t_for_image_classification_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  85798656
#
#  classifier (Dense)          multiple                  769
#
# =================================================================
# Total params: 85799425 (327.30 MB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 85798656 (327.30 MB)
# _________________________________________________________________
# Epoch 1/30
# 40/40 [==============================] - 43s 492ms/step - loss: 0.5736 - accuracy: 0.7488 - val_loss: 0.5273 - val_accuracy: 0.8040
# Epoch 2/30
# 40/40 [==============================] - 11s 278ms/step - loss: 0.4177 - accuracy: 0.8944 - val_loss: 0.4518 - val_accuracy: 0.8080
# Epoch 3/30
# 40/40 [==============================] - 11s 279ms/step - loss: 0.3411 - accuracy: 0.9032 - val_loss: 0.4044 - val_accuracy: 0.8400
# Epoch 4/30
# 40/40 [==============================] - 11s 277ms/step - loss: 0.2964 - accuracy: 0.9192 - val_loss: 0.3732 - val_accuracy: 0.8560
# Epoch 5/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2651 - accuracy: 0.9288 - val_loss: 0.3458 - val_accuracy: 0.8480
# Epoch 6/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.2411 - accuracy: 0.9368 - val_loss: 0.3313 - val_accuracy: 0.8520
# Epoch 7/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.2222 - accuracy: 0.9432 - val_loss: 0.3119 - val_accuracy: 0.8520
# Epoch 8/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.2061 - accuracy: 0.9504 - val_loss: 0.2967 - val_accuracy: 0.8640
# Epoch 9/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1924 - accuracy: 0.9576 - val_loss: 0.2849 - val_accuracy: 0.8680
# Epoch 10/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1807 - accuracy: 0.9632 - val_loss: 0.2783 - val_accuracy: 0.8680
# Epoch 11/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.1703 - accuracy: 0.9632 - val_loss: 0.2682 - val_accuracy: 0.8720
# Epoch 12/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.1609 - accuracy: 0.9656 - val_loss: 0.2610 - val_accuracy: 0.8800
# Epoch 13/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.1528 - accuracy: 0.9664 - val_loss: 0.2540 - val_accuracy: 0.8880
# Epoch 14/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1460 - accuracy: 0.9704 - val_loss: 0.2455 - val_accuracy: 0.8880
# Epoch 15/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1391 - accuracy: 0.9720 - val_loss: 0.2433 - val_accuracy: 0.8920
# Epoch 16/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1327 - accuracy: 0.9728 - val_loss: 0.2371 - val_accuracy: 0.8920
# Epoch 17/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1279 - accuracy: 0.9760 - val_loss: 0.2304 - val_accuracy: 0.9000
# Epoch 18/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1221 - accuracy: 0.9736 - val_loss: 0.2276 - val_accuracy: 0.8960
# Epoch 19/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1174 - accuracy: 0.9744 - val_loss: 0.2213 - val_accuracy: 0.8960
# Epoch 20/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1132 - accuracy: 0.9752 - val_loss: 0.2174 - val_accuracy: 0.9000
# Epoch 21/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1094 - accuracy: 0.9760 - val_loss: 0.2165 - val_accuracy: 0.8960
# Epoch 22/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.1054 - accuracy: 0.9776 - val_loss: 0.2130 - val_accuracy: 0.9000
# Epoch 23/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1016 - accuracy: 0.9784 - val_loss: 0.2110 - val_accuracy: 0.9040
# Epoch 24/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0985 - accuracy: 0.9784 - val_loss: 0.2068 - val_accuracy: 0.9000
# Epoch 25/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0955 - accuracy: 0.9784 - val_loss: 0.2030 - val_accuracy: 0.9040
# Epoch 26/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0927 - accuracy: 0.9784 - val_loss: 0.2000 - val_accuracy: 0.9160
# Epoch 27/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.0899 - accuracy: 0.9800 - val_loss: 0.1969 - val_accuracy: 0.9160
# Epoch 28/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.0873 - accuracy: 0.9784 - val_loss: 0.1947 - val_accuracy: 0.9160
# Epoch 29/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.0850 - accuracy: 0.9800 - val_loss: 0.1927 - val_accuracy: 0.9120
# Epoch 30/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0827 - accuracy: 0.9792 - val_loss: 0.1887 - val_accuracy: 0.9200
# 16/16 [==============================] - 4s 225ms/step - loss: 0.1083 - accuracy: 0.9639
# [0.10832899063825607, 0.9639278650283813]

# %% [markdown]
# ## SRCNN

# %%
train_x, train_y = create_x_y(srcnn_real_train, srcnn_adversarial_train)
val_x, val_y = create_x_y(srcnn_real_val, srcnn_adversarial_val)
test_x, test_y = create_x_y(srcnn_real_test, srcnn_adversarial_test)

vit = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k',num_labels=1, ignore_mismatched_sizes=True)
vit.trainable = True
vit.layers[0].trainable = False
vit.layers[-1].kernel_regularizer = tf.keras.regularizers.l1_l2(0.01, 0.01)
vit.layers[-1].activation = tf.keras.activations.sigmoid
vit.summary()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

vit.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
vit.fit(train_x, train_y, validation_data=(val_x, val_y), epochs=30)
vit.evaluate(test_x, test_y)
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
#   0%|          | 0/250 [00:00<?, ?it/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing TFViTForImageClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTForImageClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTForImageClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_vi_t_for_image_classification_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  85798656
#
#  classifier (Dense)          multiple                  769
#
# =================================================================
# Total params: 85799425 (327.30 MB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 85798656 (327.30 MB)
# _________________________________________________________________
# Epoch 1/30
# 40/40 [==============================] - 42s 497ms/step - loss: 0.5828 - accuracy: 0.7688 - val_loss: 0.5685 - val_accuracy: 0.7000
# Epoch 2/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.4348 - accuracy: 0.8680 - val_loss: 0.5051 - val_accuracy: 0.7400
# Epoch 3/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.3644 - accuracy: 0.8880 - val_loss: 0.4568 - val_accuracy: 0.8000
# Epoch 4/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.3208 - accuracy: 0.9016 - val_loss: 0.4274 - val_accuracy: 0.8200
# Epoch 5/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.2897 - accuracy: 0.9120 - val_loss: 0.4069 - val_accuracy: 0.8320
# Epoch 6/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.2666 - accuracy: 0.9248 - val_loss: 0.3833 - val_accuracy: 0.8360
# Epoch 7/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.2475 - accuracy: 0.9336 - val_loss: 0.3652 - val_accuracy: 0.8400
# Epoch 8/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.2315 - accuracy: 0.9384 - val_loss: 0.3517 - val_accuracy: 0.8360
# Epoch 9/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.2182 - accuracy: 0.9424 - val_loss: 0.3400 - val_accuracy: 0.8440
# Epoch 10/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2052 - accuracy: 0.9496 - val_loss: 0.3308 - val_accuracy: 0.8480
# Epoch 11/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1944 - accuracy: 0.9528 - val_loss: 0.3209 - val_accuracy: 0.8480
# Epoch 12/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1845 - accuracy: 0.9592 - val_loss: 0.3114 - val_accuracy: 0.8560
# Epoch 13/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1761 - accuracy: 0.9624 - val_loss: 0.3022 - val_accuracy: 0.8560
# Epoch 14/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1680 - accuracy: 0.9640 - val_loss: 0.2955 - val_accuracy: 0.8600
# Epoch 15/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1610 - accuracy: 0.9656 - val_loss: 0.2898 - val_accuracy: 0.8600
# Epoch 16/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1543 - accuracy: 0.9688 - val_loss: 0.2826 - val_accuracy: 0.8680
# Epoch 17/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1481 - accuracy: 0.9704 - val_loss: 0.2781 - val_accuracy: 0.8680
# Epoch 18/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1426 - accuracy: 0.9728 - val_loss: 0.2721 - val_accuracy: 0.8720
# Epoch 19/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1376 - accuracy: 0.9728 - val_loss: 0.2659 - val_accuracy: 0.8760
# Epoch 20/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1325 - accuracy: 0.9760 - val_loss: 0.2619 - val_accuracy: 0.8800
# Epoch 21/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1281 - accuracy: 0.9784 - val_loss: 0.2581 - val_accuracy: 0.8840
# Epoch 22/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1236 - accuracy: 0.9784 - val_loss: 0.2540 - val_accuracy: 0.8880
# Epoch 23/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1195 - accuracy: 0.9792 - val_loss: 0.2510 - val_accuracy: 0.8880
# Epoch 24/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1159 - accuracy: 0.9800 - val_loss: 0.2482 - val_accuracy: 0.8960
# Epoch 25/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1126 - accuracy: 0.9824 - val_loss: 0.2470 - val_accuracy: 0.8960
# Epoch 26/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1095 - accuracy: 0.9840 - val_loss: 0.2446 - val_accuracy: 0.9000
# Epoch 27/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1059 - accuracy: 0.9824 - val_loss: 0.2438 - val_accuracy: 0.9120
# Epoch 28/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1030 - accuracy: 0.9824 - val_loss: 0.2386 - val_accuracy: 0.9120
# Epoch 29/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1000 - accuracy: 0.9832 - val_loss: 0.2353 - val_accuracy: 0.9120
# Epoch 30/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0976 - accuracy: 0.9840 - val_loss: 0.2302 - val_accuracy: 0.9120
# 16/16 [==============================] - 4s 225ms/step - loss: 0.1158 - accuracy: 0.9599
# [0.11582652479410172, 0.959919810295105]

# %%
train_x, train_y = create_x_y(srcnn_real_train, srcnn_baseline_train)
val_x, val_y = create_x_y(srcnn_real_val, srcnn_baseline_val)
test_x, test_y = create_x_y(srcnn_real_test, srcnn_baseline_test)

vit = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k',num_labels=1, ignore_mismatched_sizes=True)
vit.trainable = True
vit.layers[0].trainable = False
vit.layers[-1].kernel_regularizer = tf.keras.regularizers.l1_l2(0.01, 0.01)
vit.layers[-1].activation = tf.keras.activations.sigmoid
vit.summary()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

vit.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
vit.fit(train_x, train_y, validation_data=(val_x, val_y), epochs=30)
vit.evaluate(test_x, test_y)
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
#   0%|          | 0/250 [00:00<?, ?it/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing TFViTForImageClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTForImageClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTForImageClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_vi_t_for_image_classification_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  85798656
#
#  classifier (Dense)          multiple                  769
#
# =================================================================
# Total params: 85799425 (327.30 MB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 85798656 (327.30 MB)
# _________________________________________________________________
# Epoch 1/30
# 40/40 [==============================] - 43s 493ms/step - loss: 0.6485 - accuracy: 0.6424 - val_loss: 0.7406 - val_accuracy: 0.4680
# Epoch 2/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.5930 - accuracy: 0.6904 - val_loss: 0.7955 - val_accuracy: 0.4880
# Epoch 3/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.5657 - accuracy: 0.7072 - val_loss: 0.8103 - val_accuracy: 0.4800
# Epoch 4/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.5473 - accuracy: 0.7248 - val_loss: 0.8286 - val_accuracy: 0.4920
# Epoch 5/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.5316 - accuracy: 0.7368 - val_loss: 0.8334 - val_accuracy: 0.4800
# Epoch 6/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.5193 - accuracy: 0.7504 - val_loss: 0.8286 - val_accuracy: 0.5080
# Epoch 7/30
# 40/40 [==============================] - 11s 272ms/step - loss: 0.5064 - accuracy: 0.7632 - val_loss: 0.8375 - val_accuracy: 0.5320
# Epoch 8/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4963 - accuracy: 0.7632 - val_loss: 0.8372 - val_accuracy: 0.5320
# Epoch 9/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4861 - accuracy: 0.7760 - val_loss: 0.8283 - val_accuracy: 0.5440
# Epoch 10/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4767 - accuracy: 0.7864 - val_loss: 0.8340 - val_accuracy: 0.5800
# Epoch 11/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4702 - accuracy: 0.7832 - val_loss: 0.8226 - val_accuracy: 0.5600
# Epoch 12/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4620 - accuracy: 0.7952 - val_loss: 0.8219 - val_accuracy: 0.5720
# Epoch 13/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4546 - accuracy: 0.7984 - val_loss: 0.8461 - val_accuracy: 0.5840
# Epoch 14/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4481 - accuracy: 0.8048 - val_loss: 0.8431 - val_accuracy: 0.5760
# Epoch 15/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.4442 - accuracy: 0.7992 - val_loss: 0.8328 - val_accuracy: 0.5640
# Epoch 16/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4375 - accuracy: 0.8008 - val_loss: 0.8478 - val_accuracy: 0.5760
# Epoch 17/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4307 - accuracy: 0.8168 - val_loss: 0.8355 - val_accuracy: 0.5720
# Epoch 18/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4269 - accuracy: 0.8112 - val_loss: 0.8350 - val_accuracy: 0.5880
# Epoch 19/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4208 - accuracy: 0.8224 - val_loss: 0.8354 - val_accuracy: 0.5880
# Epoch 20/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4161 - accuracy: 0.8136 - val_loss: 0.8445 - val_accuracy: 0.5960
# Epoch 21/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4124 - accuracy: 0.8336 - val_loss: 0.8428 - val_accuracy: 0.5880
# Epoch 22/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4067 - accuracy: 0.8296 - val_loss: 0.8451 - val_accuracy: 0.5840
# Epoch 23/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4028 - accuracy: 0.8328 - val_loss: 0.8633 - val_accuracy: 0.5880
# Epoch 24/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3981 - accuracy: 0.8320 - val_loss: 0.8531 - val_accuracy: 0.5800
# Epoch 25/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3941 - accuracy: 0.8384 - val_loss: 0.8504 - val_accuracy: 0.5880
# Epoch 26/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3908 - accuracy: 0.8480 - val_loss: 0.8557 - val_accuracy: 0.5920
# Epoch 27/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3863 - accuracy: 0.8496 - val_loss: 0.8397 - val_accuracy: 0.5880
# Epoch 28/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3854 - accuracy: 0.8352 - val_loss: 0.8734 - val_accuracy: 0.6000
# Epoch 29/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3809 - accuracy: 0.8440 - val_loss: 0.8666 - val_accuracy: 0.5920
# Epoch 30/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.3763 - accuracy: 0.8488 - val_loss: 0.8776 - val_accuracy: 0.5960
# 16/16 [==============================] - 4s 225ms/step - loss: 0.7548 - accuracy: 0.6353
# [0.754755973815918, 0.6352705359458923]

# %%
train_x, train_y = create_x_y(srcnn_real_train, srcnn_faceshift_train)
val_x, val_y = create_x_y(srcnn_real_val, srcnn_faceshift_val)
test_x, test_y = create_x_y(srcnn_real_test, srcnn_faceshift_test)

vit = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k',num_labels=1, ignore_mismatched_sizes=True)
vit.trainable = True
vit.layers[0].trainable = False
vit.layers[-1].kernel_regularizer = tf.keras.regularizers.l1_l2(0.01, 0.01)
vit.layers[-1].activation = tf.keras.activations.sigmoid
vit.summary()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

vit.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
vit.fit(train_x, train_y, validation_data=(val_x, val_y), epochs=30)
vit.evaluate(test_x, test_y)
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing TFViTForImageClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTForImageClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTForImageClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_vi_t_for_image_classification_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  85798656
#
#  classifier (Dense)          multiple                  769
#
# =================================================================
# Total params: 85799425 (327.30 MB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 85798656 (327.30 MB)
# _________________________________________________________________
# Epoch 1/30
# 40/40 [==============================] - 42s 497ms/step - loss: 0.6080 - accuracy: 0.7104 - val_loss: 0.6826 - val_accuracy: 0.5200
# Epoch 2/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.4945 - accuracy: 0.8056 - val_loss: 0.6598 - val_accuracy: 0.5360
# Epoch 3/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.4329 - accuracy: 0.8456 - val_loss: 0.6276 - val_accuracy: 0.6160
# Epoch 4/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.3896 - accuracy: 0.8592 - val_loss: 0.5930 - val_accuracy: 0.6480
# Epoch 5/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3548 - accuracy: 0.8784 - val_loss: 0.5562 - val_accuracy: 0.6880
# Epoch 6/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.3276 - accuracy: 0.8960 - val_loss: 0.5182 - val_accuracy: 0.7160
# Epoch 7/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3031 - accuracy: 0.9088 - val_loss: 0.4926 - val_accuracy: 0.7240
# Epoch 8/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.2831 - accuracy: 0.9240 - val_loss: 0.4537 - val_accuracy: 0.7560
# Epoch 9/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2652 - accuracy: 0.9392 - val_loss: 0.4240 - val_accuracy: 0.7840
# Epoch 10/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2497 - accuracy: 0.9408 - val_loss: 0.4135 - val_accuracy: 0.7960
# Epoch 11/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2353 - accuracy: 0.9496 - val_loss: 0.3913 - val_accuracy: 0.8080
# Epoch 12/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2227 - accuracy: 0.9528 - val_loss: 0.3762 - val_accuracy: 0.8200
# Epoch 13/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2118 - accuracy: 0.9568 - val_loss: 0.3710 - val_accuracy: 0.8200
# Epoch 14/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.2022 - accuracy: 0.9592 - val_loss: 0.3554 - val_accuracy: 0.8320
# Epoch 15/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1930 - accuracy: 0.9616 - val_loss: 0.3376 - val_accuracy: 0.8600
# Epoch 16/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1850 - accuracy: 0.9632 - val_loss: 0.3237 - val_accuracy: 0.8720
# Epoch 17/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1778 - accuracy: 0.9688 - val_loss: 0.3158 - val_accuracy: 0.8680
# Epoch 18/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1698 - accuracy: 0.9704 - val_loss: 0.3078 - val_accuracy: 0.8720
# Epoch 19/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1636 - accuracy: 0.9696 - val_loss: 0.2976 - val_accuracy: 0.8840
# Epoch 20/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1572 - accuracy: 0.9728 - val_loss: 0.2869 - val_accuracy: 0.8960
# Epoch 21/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1515 - accuracy: 0.9736 - val_loss: 0.2746 - val_accuracy: 0.9000
# Epoch 22/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1460 - accuracy: 0.9768 - val_loss: 0.2719 - val_accuracy: 0.9000
# Epoch 23/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1414 - accuracy: 0.9752 - val_loss: 0.2676 - val_accuracy: 0.9000
# Epoch 24/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1366 - accuracy: 0.9776 - val_loss: 0.2599 - val_accuracy: 0.9040
# Epoch 25/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1323 - accuracy: 0.9776 - val_loss: 0.2545 - val_accuracy: 0.9040
# Epoch 26/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1281 - accuracy: 0.9800 - val_loss: 0.2515 - val_accuracy: 0.9040
# Epoch 27/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1242 - accuracy: 0.9784 - val_loss: 0.2455 - val_accuracy: 0.9040
# Epoch 28/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1205 - accuracy: 0.9800 - val_loss: 0.2392 - val_accuracy: 0.9080
# Epoch 29/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1169 - accuracy: 0.9832 - val_loss: 0.2334 - val_accuracy: 0.9080
# Epoch 30/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1135 - accuracy: 0.9832 - val_loss: 0.2288 - val_accuracy: 0.9080
# 16/16 [==============================] - 4s 224ms/step - loss: 0.1881 - accuracy: 0.9438
# [0.1880931556224823, 0.9437751173973083]

# %% [markdown]
# ## Bicubic Interpolation

# %%
train_x, train_y = create_x_y(bicubic_real_train, bicubic_faceshift_train)
val_x, val_y = create_x_y(bicubic_real_val, bicubic_faceshift_val)
test_x, test_y = create_x_y(bicubic_real_test, bicubic_faceshift_test)

vit = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k',num_labels=1, ignore_mismatched_sizes=True)
vit.trainable = True
vit.layers[0].trainable = False
vit.layers[-1].kernel_regularizer = tf.keras.regularizers.l1_l2(0.01, 0.01)
vit.layers[-1].activation = tf.keras.activations.sigmoid
vit.summary()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

vit.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
vit.fit(train_x, train_y, validation_data=(val_x, val_y), epochs=30)
vit.evaluate(test_x, test_y)
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing TFViTForImageClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTForImageClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTForImageClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_vi_t_for_image_classification_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  85798656
#
#  classifier (Dense)          multiple                  769
#
# =================================================================
# Total params: 85799425 (327.30 MB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 85798656 (327.30 MB)
# _________________________________________________________________
# Epoch 1/30
# 40/40 [==============================] - 42s 491ms/step - loss: 0.5569 - accuracy: 0.9048 - val_loss: 0.5217 - val_accuracy: 0.8440
# Epoch 2/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.3771 - accuracy: 0.9544 - val_loss: 0.4312 - val_accuracy: 0.8680
# Epoch 3/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2873 - accuracy: 0.9624 - val_loss: 0.3708 - val_accuracy: 0.8920
# Epoch 4/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2336 - accuracy: 0.9680 - val_loss: 0.3206 - val_accuracy: 0.9080
# Epoch 5/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.1978 - accuracy: 0.9752 - val_loss: 0.2895 - val_accuracy: 0.9160
# Epoch 6/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1721 - accuracy: 0.9792 - val_loss: 0.2648 - val_accuracy: 0.9240
# Epoch 7/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.1516 - accuracy: 0.9832 - val_loss: 0.2467 - val_accuracy: 0.9240
# Epoch 8/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1355 - accuracy: 0.9896 - val_loss: 0.2298 - val_accuracy: 0.9320
# Epoch 9/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1223 - accuracy: 0.9896 - val_loss: 0.2165 - val_accuracy: 0.9280
# Epoch 10/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1115 - accuracy: 0.9896 - val_loss: 0.2029 - val_accuracy: 0.9360
# Epoch 11/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1024 - accuracy: 0.9928 - val_loss: 0.1936 - val_accuracy: 0.9400
# Epoch 12/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0944 - accuracy: 0.9944 - val_loss: 0.1830 - val_accuracy: 0.9400
# Epoch 13/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0875 - accuracy: 0.9944 - val_loss: 0.1756 - val_accuracy: 0.9560
# Epoch 14/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0815 - accuracy: 0.9952 - val_loss: 0.1686 - val_accuracy: 0.9560
# Epoch 15/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0762 - accuracy: 0.9960 - val_loss: 0.1613 - val_accuracy: 0.9560
# Epoch 16/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0715 - accuracy: 0.9960 - val_loss: 0.1557 - val_accuracy: 0.9560
# Epoch 17/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0670 - accuracy: 0.9968 - val_loss: 0.1506 - val_accuracy: 0.9560
# Epoch 18/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0633 - accuracy: 0.9968 - val_loss: 0.1452 - val_accuracy: 0.9560
# Epoch 19/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0598 - accuracy: 0.9976 - val_loss: 0.1390 - val_accuracy: 0.9600
# Epoch 20/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0566 - accuracy: 0.9984 - val_loss: 0.1352 - val_accuracy: 0.9600
# Epoch 21/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0536 - accuracy: 0.9984 - val_loss: 0.1313 - val_accuracy: 0.9600
# Epoch 22/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0509 - accuracy: 0.9984 - val_loss: 0.1283 - val_accuracy: 0.9600
# Epoch 23/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0484 - accuracy: 0.9992 - val_loss: 0.1245 - val_accuracy: 0.9560
# Epoch 24/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0462 - accuracy: 0.9992 - val_loss: 0.1210 - val_accuracy: 0.9600
# Epoch 25/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0440 - accuracy: 0.9992 - val_loss: 0.1176 - val_accuracy: 0.9640
# Epoch 26/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0420 - accuracy: 0.9992 - val_loss: 0.1138 - val_accuracy: 0.9600
# Epoch 27/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0402 - accuracy: 0.9992 - val_loss: 0.1121 - val_accuracy: 0.9600
# Epoch 28/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0385 - accuracy: 0.9992 - val_loss: 0.1104 - val_accuracy: 0.9600
# Epoch 29/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0367 - accuracy: 0.9992 - val_loss: 0.1084 - val_accuracy: 0.9600
# Epoch 30/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0352 - accuracy: 0.9992 - val_loss: 0.1053 - val_accuracy: 0.9680
# 16/16 [==============================] - 4s 225ms/step - loss: 0.0724 - accuracy: 0.9819
# [0.07240816950798035, 0.9819276928901672]

# %%
train_x, train_y = create_x_y(bicubic_real_train, bicubic_baseline_train)
val_x, val_y = create_x_y(bicubic_real_val, bicubic_baseline_val)
test_x, test_y = create_x_y(bicubic_real_test, bicubic_baseline_test)

vit = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k',num_labels=1, ignore_mismatched_sizes=True)
vit.trainable = True
vit.layers[0].trainable = False
vit.layers[-1].kernel_regularizer = tf.keras.regularizers.l1_l2(0.01, 0.01)
vit.layers[-1].activation = tf.keras.activations.sigmoid
vit.summary()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

vit.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
vit.fit(train_x, train_y, validation_data=(val_x, val_y), epochs=30)
vit.evaluate(test_x, test_y)
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
#   0%|          | 0/250 [00:00<?, ?it/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing TFViTForImageClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTForImageClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTForImageClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_vi_t_for_image_classification_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  85798656
#
#  classifier (Dense)          multiple                  769
#
# =================================================================
# Total params: 85799425 (327.30 MB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 85798656 (327.30 MB)
# _________________________________________________________________
# Epoch 1/30
# 40/40 [==============================] - 43s 521ms/step - loss: 0.6467 - accuracy: 0.6632 - val_loss: 0.7536 - val_accuracy: 0.4720
# Epoch 2/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.5889 - accuracy: 0.7024 - val_loss: 0.7803 - val_accuracy: 0.4760
# Epoch 3/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.5611 - accuracy: 0.7232 - val_loss: 0.8180 - val_accuracy: 0.4760
# Epoch 4/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.5408 - accuracy: 0.7440 - val_loss: 0.8265 - val_accuracy: 0.4840
# Epoch 5/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.5239 - accuracy: 0.7552 - val_loss: 0.8306 - val_accuracy: 0.4880
# Epoch 6/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.5091 - accuracy: 0.7720 - val_loss: 0.8318 - val_accuracy: 0.4920
# Epoch 7/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4959 - accuracy: 0.7760 - val_loss: 0.8408 - val_accuracy: 0.4960
# Epoch 8/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4844 - accuracy: 0.7776 - val_loss: 0.8504 - val_accuracy: 0.5200
# Epoch 9/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4737 - accuracy: 0.7912 - val_loss: 0.8415 - val_accuracy: 0.5240
# Epoch 10/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.4639 - accuracy: 0.7896 - val_loss: 0.8430 - val_accuracy: 0.5240
# Epoch 11/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.4551 - accuracy: 0.8056 - val_loss: 0.8354 - val_accuracy: 0.5320
# Epoch 12/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.4463 - accuracy: 0.8072 - val_loss: 0.8373 - val_accuracy: 0.5360
# Epoch 13/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4391 - accuracy: 0.8056 - val_loss: 0.8313 - val_accuracy: 0.5360
# Epoch 14/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.4316 - accuracy: 0.8160 - val_loss: 0.8336 - val_accuracy: 0.5360
# Epoch 15/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4280 - accuracy: 0.8160 - val_loss: 0.8284 - val_accuracy: 0.5440
# Epoch 16/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.4201 - accuracy: 0.8280 - val_loss: 0.8352 - val_accuracy: 0.5320
# Epoch 17/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4134 - accuracy: 0.8144 - val_loss: 0.8412 - val_accuracy: 0.5560
# Epoch 18/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4081 - accuracy: 0.8216 - val_loss: 0.8361 - val_accuracy: 0.5560
# Epoch 19/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.4017 - accuracy: 0.8272 - val_loss: 0.8402 - val_accuracy: 0.5520
# Epoch 20/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3968 - accuracy: 0.8360 - val_loss: 0.8315 - val_accuracy: 0.5520
# Epoch 21/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.3914 - accuracy: 0.8336 - val_loss: 0.8356 - val_accuracy: 0.5520
# Epoch 22/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3868 - accuracy: 0.8376 - val_loss: 0.8323 - val_accuracy: 0.5560
# Epoch 23/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3824 - accuracy: 0.8376 - val_loss: 0.8371 - val_accuracy: 0.5520
# Epoch 24/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.3777 - accuracy: 0.8408 - val_loss: 0.8419 - val_accuracy: 0.5520
# Epoch 25/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3733 - accuracy: 0.8416 - val_loss: 0.8428 - val_accuracy: 0.5520
# Epoch 26/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3695 - accuracy: 0.8528 - val_loss: 0.8429 - val_accuracy: 0.5440
# Epoch 27/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3659 - accuracy: 0.8536 - val_loss: 0.8360 - val_accuracy: 0.5400
# Epoch 28/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.3610 - accuracy: 0.8592 - val_loss: 0.8318 - val_accuracy: 0.5520
# Epoch 29/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.3584 - accuracy: 0.8616 - val_loss: 0.8095 - val_accuracy: 0.5480
# Epoch 30/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3540 - accuracy: 0.8672 - val_loss: 0.8308 - val_accuracy: 0.5560
# 16/16 [==============================] - 4s 225ms/step - loss: 0.7335 - accuracy: 0.6453
# [0.7335337996482849, 0.6452905535697937]

# %%
train_x, train_y = create_x_y(bicubic_real_train, bicubic_adversarial_train)
val_x, val_y = create_x_y(bicubic_real_val, bicubic_adversarial_val)
test_x, test_y = create_x_y(bicubic_real_test, bicubic_adversarial_test)

vit = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k',num_labels=1, ignore_mismatched_sizes=True)
vit.trainable = True
vit.layers[0].trainable = False
vit.layers[-1].kernel_regularizer = tf.keras.regularizers.l1_l2(0.01, 0.01)
vit.layers[-1].activation = tf.keras.activations.sigmoid
vit.summary()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

vit.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
vit.fit(train_x, train_y, validation_data=(val_x, val_y), epochs=30)
vit.evaluate(test_x, test_y)
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
#   0%|          | 0/250 [00:00<?, ?it/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing TFViTForImageClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTForImageClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTForImageClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_vi_t_for_image_classification_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  85798656
#
#  classifier (Dense)          multiple                  769
#
# =================================================================
# Total params: 85799425 (327.30 MB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 85798656 (327.30 MB)
# _________________________________________________________________
# Epoch 1/30
# 40/40 [==============================] - 42s 491ms/step - loss: 0.5844 - accuracy: 0.7432 - val_loss: 0.5557 - val_accuracy: 0.7440
# Epoch 2/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.4444 - accuracy: 0.8512 - val_loss: 0.4874 - val_accuracy: 0.7720
# Epoch 3/30
# 40/40 [==============================] - 11s 276ms/step - loss: 0.3734 - accuracy: 0.8848 - val_loss: 0.4451 - val_accuracy: 0.7920
# Epoch 4/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.3286 - accuracy: 0.9024 - val_loss: 0.4048 - val_accuracy: 0.8160
# Epoch 5/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.2942 - accuracy: 0.9144 - val_loss: 0.3769 - val_accuracy: 0.8400
# Epoch 6/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.2679 - accuracy: 0.9312 - val_loss: 0.3524 - val_accuracy: 0.8520
# Epoch 7/30
# 40/40 [==============================] - 11s 273ms/step - loss: 0.2472 - accuracy: 0.9440 - val_loss: 0.3364 - val_accuracy: 0.8520
# Epoch 8/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.2297 - accuracy: 0.9536 - val_loss: 0.3198 - val_accuracy: 0.8600
# Epoch 9/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.2148 - accuracy: 0.9576 - val_loss: 0.3050 - val_accuracy: 0.8720
# Epoch 10/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.2012 - accuracy: 0.9648 - val_loss: 0.2925 - val_accuracy: 0.8760
# Epoch 11/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1896 - accuracy: 0.9680 - val_loss: 0.2790 - val_accuracy: 0.8840
# Epoch 12/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1790 - accuracy: 0.9712 - val_loss: 0.2688 - val_accuracy: 0.8920
# Epoch 13/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1694 - accuracy: 0.9736 - val_loss: 0.2610 - val_accuracy: 0.8960
# Epoch 14/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1611 - accuracy: 0.9760 - val_loss: 0.2547 - val_accuracy: 0.9000
# Epoch 15/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1533 - accuracy: 0.9760 - val_loss: 0.2478 - val_accuracy: 0.9000
# Epoch 16/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1463 - accuracy: 0.9760 - val_loss: 0.2419 - val_accuracy: 0.9040
# Epoch 17/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1396 - accuracy: 0.9784 - val_loss: 0.2347 - val_accuracy: 0.9000
# Epoch 18/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1340 - accuracy: 0.9768 - val_loss: 0.2302 - val_accuracy: 0.9040
# Epoch 19/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1282 - accuracy: 0.9824 - val_loss: 0.2247 - val_accuracy: 0.9080
# Epoch 20/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1238 - accuracy: 0.9832 - val_loss: 0.2207 - val_accuracy: 0.9120
# Epoch 21/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1184 - accuracy: 0.9840 - val_loss: 0.2162 - val_accuracy: 0.9120
# Epoch 22/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1143 - accuracy: 0.9840 - val_loss: 0.2129 - val_accuracy: 0.9160
# Epoch 23/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1111 - accuracy: 0.9856 - val_loss: 0.2083 - val_accuracy: 0.9160
# Epoch 24/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.1069 - accuracy: 0.9840 - val_loss: 0.2061 - val_accuracy: 0.9160
# Epoch 25/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.1029 - accuracy: 0.9864 - val_loss: 0.2030 - val_accuracy: 0.9160
# Epoch 26/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0998 - accuracy: 0.9880 - val_loss: 0.2004 - val_accuracy: 0.9160
# Epoch 27/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0965 - accuracy: 0.9880 - val_loss: 0.1985 - val_accuracy: 0.9160
# Epoch 28/30
# 40/40 [==============================] - 11s 275ms/step - loss: 0.0938 - accuracy: 0.9888 - val_loss: 0.1966 - val_accuracy: 0.9200
# Epoch 29/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0910 - accuracy: 0.9896 - val_loss: 0.1955 - val_accuracy: 0.9240
# Epoch 30/30
# 40/40 [==============================] - 11s 274ms/step - loss: 0.0888 - accuracy: 0.9888 - val_loss: 0.1945 - val_accuracy: 0.9240
# 16/16 [==============================] - 4s 226ms/step - loss: 0.1116 - accuracy: 0.9619
# [0.11155572533607483, 0.9619238376617432]

# %% [markdown]
# ## SR3

# %%
train_x, train_y = create_x_y(sr3_real_train, sr3_faceshift_train)
test_x, test_y = create_x_y(sr3_real_test, sr3_faceshift_test)

vit = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k',num_labels=1, ignore_mismatched_sizes=True)
vit.trainable = True
vit.layers[0].trainable = False
vit.layers[-1].kernel_regularizer = tf.keras.regularizers.l1_l2(0.01, 0.01)
vit.layers[-1].activation = tf.keras.activations.sigmoid
vit.summary()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

vit.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
vit.fit(train_x, train_y, epochs=30)
vit.evaluate(test_x, test_y)
# Out:
#   0%|          | 0/75 [00:00<?, ?it/s]
#   0%|          | 0/75 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing TFViTForImageClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTForImageClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTForImageClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_vi_t_for_image_classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  85798656
#
#  classifier (Dense)          multiple                  769
#
# =================================================================
# Total params: 85799425 (327.30 MB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 85798656 (327.30 MB)
# _________________________________________________________________
# Epoch 1/30
# WARNING:tensorflow:AutoGraph could not transform <function infer_framework at 0x7ca0dbced6c0> and will run it as-is.
# Cause: for/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function infer_framework at 0x7ca0dbced6c0> and will run it as-is.
# Cause: for/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 5/5 [==============================] - 54s 378ms/step - loss: 0.6941 - accuracy: 0.5333
# Epoch 2/30
# 5/5 [==============================] - 2s 378ms/step - loss: 0.6498 - accuracy: 0.8867
# Epoch 3/30
# 5/5 [==============================] - 2s 383ms/step - loss: 0.6082 - accuracy: 0.9467
# Epoch 4/30
# 5/5 [==============================] - 2s 376ms/step - loss: 0.5733 - accuracy: 0.9467
# Epoch 5/30
# 5/5 [==============================] - 2s 374ms/step - loss: 0.5391 - accuracy: 0.9467
# Epoch 6/30
# 5/5 [==============================] - 2s 375ms/step - loss: 0.5087 - accuracy: 0.9467
# Epoch 7/30
# 5/5 [==============================] - 2s 374ms/step - loss: 0.4809 - accuracy: 0.9800
# Epoch 8/30
# 5/5 [==============================] - 2s 378ms/step - loss: 0.4549 - accuracy: 0.9800
# Epoch 9/30
# 5/5 [==============================] - 2s 383ms/step - loss: 0.4316 - accuracy: 0.9800
# Epoch 10/30
# 5/5 [==============================] - 2s 390ms/step - loss: 0.4108 - accuracy: 0.9800
# Epoch 11/30
# 5/5 [==============================] - 2s 380ms/step - loss: 0.3909 - accuracy: 0.9800
# Epoch 12/30
# 5/5 [==============================] - 2s 381ms/step - loss: 0.3733 - accuracy: 0.9800
# Epoch 13/30
# 5/5 [==============================] - 2s 380ms/step - loss: 0.3572 - accuracy: 0.9800
# Epoch 14/30
# 5/5 [==============================] - 2s 380ms/step - loss: 0.3420 - accuracy: 0.9800
# Epoch 15/30
# 5/5 [==============================] - 2s 380ms/step - loss: 0.3282 - accuracy: 0.9800
# Epoch 16/30
# 5/5 [==============================] - 2s 391ms/step - loss: 0.3156 - accuracy: 0.9867
# Epoch 17/30
# 5/5 [==============================] - 2s 391ms/step - loss: 0.3041 - accuracy: 0.9867
# Epoch 18/30
# 5/5 [==============================] - 2s 384ms/step - loss: 0.2929 - accuracy: 0.9867
# Epoch 19/30
# 5/5 [==============================] - 2s 384ms/step - loss: 0.2825 - accuracy: 0.9867
# Epoch 20/30
# 5/5 [==============================] - 2s 387ms/step - loss: 0.2728 - accuracy: 0.9867
# Epoch 21/30
# 5/5 [==============================] - 2s 386ms/step - loss: 0.2642 - accuracy: 0.9867
# Epoch 22/30
# 5/5 [==============================] - 2s 389ms/step - loss: 0.2557 - accuracy: 0.9867
# Epoch 23/30
# 5/5 [==============================] - 2s 400ms/step - loss: 0.2478 - accuracy: 0.9867
# Epoch 24/30
# 5/5 [==============================] - 2s 395ms/step - loss: 0.2403 - accuracy: 0.9867
# Epoch 25/30
# 5/5 [==============================] - 2s 388ms/step - loss: 0.2332 - accuracy: 0.9867
# Epoch 26/30
# 5/5 [==============================] - 2s 390ms/step - loss: 0.2267 - accuracy: 0.9867
# Epoch 27/30
# 5/5 [==============================] - 2s 405ms/step - loss: 0.2202 - accuracy: 0.9867
# Epoch 28/30
# 5/5 [==============================] - 2s 390ms/step - loss: 0.2142 - accuracy: 0.9867
# Epoch 29/30
# 5/5 [==============================] - 2s 397ms/step - loss: 0.2086 - accuracy: 0.9867
# Epoch 30/30
# 5/5 [==============================] - 2s 399ms/step - loss: 0.2031 - accuracy: 0.9867
# 2/2 [==============================] - 10s 295ms/step - loss: 0.3436 - accuracy: 0.8400
# [0.3436296582221985, 0.8399999737739563]

# %%
train_x, train_y = create_x_y(sr3_real_train, sr3_baseline_train)
test_x, test_y = create_x_y(sr3_real_test, sr3_baseline_test)

vit = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k',num_labels=1, ignore_mismatched_sizes=True)
vit.trainable = True
vit.layers[0].trainable = False
vit.layers[-1].kernel_regularizer = tf.keras.regularizers.l1_l2(0.01, 0.01)
vit.layers[-1].activation = tf.keras.activations.sigmoid
vit.summary()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

vit.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
vit.fit(train_x, train_y, epochs=30)
vit.evaluate(test_x, test_y)
# Out:
#   0%|          | 0/75 [00:00<?, ?it/s]
#   0%|          | 0/75 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing TFViTForImageClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTForImageClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTForImageClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_vi_t_for_image_classification_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  85798656
#
#  classifier (Dense)          multiple                  769
#
# =================================================================
# Total params: 85799425 (327.30 MB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 85798656 (327.30 MB)
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 28s 395ms/step - loss: 0.6952 - accuracy: 0.4400
# Epoch 2/30
# 5/5 [==============================] - 2s 401ms/step - loss: 0.6799 - accuracy: 0.5733
# Epoch 3/30
# 5/5 [==============================] - 2s 399ms/step - loss: 0.6668 - accuracy: 0.7267
# Epoch 4/30
# 5/5 [==============================] - 2s 391ms/step - loss: 0.6543 - accuracy: 0.7800
# Epoch 5/30
# 5/5 [==============================] - 2s 392ms/step - loss: 0.6433 - accuracy: 0.7933
# Epoch 6/30
# 5/5 [==============================] - 2s 394ms/step - loss: 0.6321 - accuracy: 0.7933
# Epoch 7/30
# 5/5 [==============================] - 2s 394ms/step - loss: 0.6214 - accuracy: 0.7933
# Epoch 8/30
# 5/5 [==============================] - 2s 396ms/step - loss: 0.6113 - accuracy: 0.8067
# Epoch 9/30
# 5/5 [==============================] - 2s 406ms/step - loss: 0.6019 - accuracy: 0.8267
# Epoch 10/30
# 5/5 [==============================] - 2s 400ms/step - loss: 0.5937 - accuracy: 0.8267
# Epoch 11/30
# 5/5 [==============================] - 2s 398ms/step - loss: 0.5856 - accuracy: 0.8267
# Epoch 12/30
# 5/5 [==============================] - 2s 397ms/step - loss: 0.5773 - accuracy: 0.8267
# Epoch 13/30
# 5/5 [==============================] - 2s 399ms/step - loss: 0.5699 - accuracy: 0.8267
# Epoch 14/30
# 5/5 [==============================] - 2s 400ms/step - loss: 0.5625 - accuracy: 0.8267
# Epoch 15/30
# 5/5 [==============================] - 2s 410ms/step - loss: 0.5551 - accuracy: 0.8267
# Epoch 16/30
# 5/5 [==============================] - 2s 409ms/step - loss: 0.5486 - accuracy: 0.8267
# Epoch 17/30
# 5/5 [==============================] - 2s 403ms/step - loss: 0.5416 - accuracy: 0.8333
# Epoch 18/30
# 5/5 [==============================] - 2s 405ms/step - loss: 0.5349 - accuracy: 0.8333
# Epoch 19/30
# 5/5 [==============================] - 2s 409ms/step - loss: 0.5287 - accuracy: 0.8400
# Epoch 20/30
# 5/5 [==============================] - 2s 409ms/step - loss: 0.5226 - accuracy: 0.8333
# Epoch 21/30
# 5/5 [==============================] - 2s 413ms/step - loss: 0.5167 - accuracy: 0.8400
# Epoch 22/30
# 5/5 [==============================] - 2s 417ms/step - loss: 0.5113 - accuracy: 0.8467
# Epoch 23/30
# 5/5 [==============================] - 2s 410ms/step - loss: 0.5055 - accuracy: 0.8533
# Epoch 24/30
# 5/5 [==============================] - 2s 409ms/step - loss: 0.4994 - accuracy: 0.8533
# Epoch 25/30
# 5/5 [==============================] - 2s 408ms/step - loss: 0.4939 - accuracy: 0.8600
# Epoch 26/30
# 5/5 [==============================] - 2s 406ms/step - loss: 0.4901 - accuracy: 0.8600
# Epoch 27/30
# 5/5 [==============================] - 2s 405ms/step - loss: 0.4846 - accuracy: 0.8667
# Epoch 28/30
# 5/5 [==============================] - 2s 417ms/step - loss: 0.4798 - accuracy: 0.8667
# Epoch 29/30
# 5/5 [==============================] - 2s 406ms/step - loss: 0.4740 - accuracy: 0.8733
# Epoch 30/30
# 5/5 [==============================] - 2s 401ms/step - loss: 0.4693 - accuracy: 0.8667
# 2/2 [==============================] - 10s 258ms/step - loss: 0.5998 - accuracy: 0.7600
# [0.5998238921165466, 0.7599999904632568]

# %%
train_x, train_y = create_x_y(sr3_real_train, sr3_adversarial_train)
test_x, test_y = create_x_y(sr3_real_test, sr3_adversarial_test)

vit = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k',num_labels=1, ignore_mismatched_sizes=True)
vit.trainable = True
vit.layers[0].trainable = False
vit.layers[-1].kernel_regularizer = tf.keras.regularizers.l1_l2(0.01, 0.01)
vit.layers[-1].activation = tf.keras.activations.sigmoid
vit.summary()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

vit.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
vit.fit(train_x, train_y, epochs=30)
vit.evaluate(test_x, test_y)
# Out:
#   0%|          | 0/75 [00:00<?, ?it/s]
#   0%|          | 0/75 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing TFViTForImageClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTForImageClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTForImageClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_vi_t_for_image_classification_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  85798656
#
#  classifier (Dense)          multiple                  769
#
# =================================================================
# Total params: 85799425 (327.30 MB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 85798656 (327.30 MB)
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 28s 395ms/step - loss: 0.6811 - accuracy: 0.6733
# Epoch 2/30
# 5/5 [==============================] - 2s 404ms/step - loss: 0.6514 - accuracy: 0.8333
# Epoch 3/30
# 5/5 [==============================] - 2s 397ms/step - loss: 0.6244 - accuracy: 0.8533
# Epoch 4/30
# 5/5 [==============================] - 2s 400ms/step - loss: 0.5986 - accuracy: 0.8867
# Epoch 5/30
# 5/5 [==============================] - 2s 398ms/step - loss: 0.5750 - accuracy: 0.9533
# Epoch 6/30
# 5/5 [==============================] - 2s 400ms/step - loss: 0.5533 - accuracy: 0.9467
# Epoch 7/30
# 5/5 [==============================] - 2s 400ms/step - loss: 0.5331 - accuracy: 0.9333
# Epoch 8/30
# 5/5 [==============================] - 2s 413ms/step - loss: 0.5132 - accuracy: 0.9267
# Epoch 9/30
# 5/5 [==============================] - 2s 411ms/step - loss: 0.4957 - accuracy: 0.9200
# Epoch 10/30
# 5/5 [==============================] - 2s 404ms/step - loss: 0.4792 - accuracy: 0.9267
# Epoch 11/30
# 5/5 [==============================] - 2s 405ms/step - loss: 0.4638 - accuracy: 0.9333
# Epoch 12/30
# 5/5 [==============================] - 2s 408ms/step - loss: 0.4491 - accuracy: 0.9333
# Epoch 13/30
# 5/5 [==============================] - 2s 407ms/step - loss: 0.4354 - accuracy: 0.9400
# Epoch 14/30
# 5/5 [==============================] - 2s 415ms/step - loss: 0.4224 - accuracy: 0.9533
# Epoch 15/30
# 5/5 [==============================] - 2s 421ms/step - loss: 0.4099 - accuracy: 0.9600
# Epoch 16/30
# 5/5 [==============================] - 2s 411ms/step - loss: 0.3983 - accuracy: 0.9667
# Epoch 17/30
# 5/5 [==============================] - 2s 411ms/step - loss: 0.3875 - accuracy: 0.9733
# Epoch 18/30
# 5/5 [==============================] - 2s 412ms/step - loss: 0.3771 - accuracy: 0.9733
# Epoch 19/30
# 5/5 [==============================] - 2s 412ms/step - loss: 0.3672 - accuracy: 0.9733
# Epoch 20/30
# 5/5 [==============================] - 2s 411ms/step - loss: 0.3577 - accuracy: 0.9733
# Epoch 21/30
# 5/5 [==============================] - 2s 414ms/step - loss: 0.3488 - accuracy: 0.9667
# Epoch 22/30
# 5/5 [==============================] - 2s 406ms/step - loss: 0.3403 - accuracy: 0.9667
# Epoch 23/30
# 5/5 [==============================] - 2s 405ms/step - loss: 0.3320 - accuracy: 0.9667
# Epoch 24/30
# 5/5 [==============================] - 2s 404ms/step - loss: 0.3242 - accuracy: 0.9733
# Epoch 25/30
# 5/5 [==============================] - 2s 404ms/step - loss: 0.3168 - accuracy: 0.9733
# Epoch 26/30
# 5/5 [==============================] - 2s 403ms/step - loss: 0.3097 - accuracy: 0.9800
# Epoch 27/30
# 5/5 [==============================] - 2s 410ms/step - loss: 0.3024 - accuracy: 0.9800
# Epoch 28/30
# 5/5 [==============================] - 2s 407ms/step - loss: 0.2960 - accuracy: 0.9867
# Epoch 29/30
# 5/5 [==============================] - 2s 403ms/step - loss: 0.2895 - accuracy: 0.9867
# Epoch 30/30
# 5/5 [==============================] - 2s 399ms/step - loss: 0.2834 - accuracy: 0.9867
# 2/2 [==============================] - 9s 255ms/step - loss: 0.3724 - accuracy: 0.8800
# [0.3724135458469391, 0.8799999952316284]
